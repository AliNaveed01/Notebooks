# %% [markdown]
# Naveed Ali
#
# 20L-1244
#
# Data  Visualization and Analysis
#
# Lab 4

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import math
import cv2
import scipy as sp
import argparse
import copy
from skimage.util import random_noise

# %%
def greyimage(img):
    R,G,B = img[:,:,0], img[:,:,1], img[:,:,2]
    grayscale = ((0.3 * R) + (0.59 * G) + (0.11 * B))
    return grayscale

# %%
for i in range(0, 10):
    img = mpimg.imread('cat.'+str(i)+'.jpg')
    img = greyimage(img)
    cv2.imwrite('greycat.'+str(i)+'.jpg', img)
    plt.imshow(img, cmap='gray')
    plt.show()

# %%
for i in range(0, 10):
    img = mpimg.imread('dog.'+str(i)+'.jpg')
    img = greyimage(img)
    cv2.imwrite('greydog.'+str(i)+'.jpg', img)
    plt.imshow(img, cmap='gray')
    plt.show()

# %% [markdown]
# GAUSSIAN FILTER

# %%
def gaussian_filter(img, kernel):
    kernel_length = len(kernel)
    imx, imy = img.shape[0:2]
    new_image = img[::, ::]
    for i in range(kernel_length, imx - kernel_length):
        for j in range(kernel_length, imy - kernel_length):
            acc = 0
            for ki in range(kernel_length):
                for kj in range(kernel_length):
                    acc += img[i+ki-2][j+kj-2] * kernel[ki][kj]
            new_image[i][j] = acc
    return new_image

# %%
gaussian_fil = np.array([[1,2,1],[2,4,2],[1,2,1]])/16

for i in range(1, 10):

    img = mpimg.imread('greydog.' + str(i) + '.jpg')
    grey_img = gaussian_filter(copy.deepcopy(img), gaussian_fil)
    plt.imshow(grey_img, cmap='gray')
    plt.show()

# %% [markdown]
# MEAN FILTER
